# %%
import duckdb

resultado = duckdb.sql("SELECT * FROM read_csv('complete_ecommerce_data.csv', encoding = 'latin-1') WHERE UnitPrice < 0").show()
# Out:
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │        10624 │
# └──────────────┘
